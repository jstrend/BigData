# %% [markdown]
# <a href="https://colab.research.google.com/github/jstrend/BigData/blob/main/02_jupyter_1%EC%B0%A8%EC%9B%90%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # jupyter 1차원 자료구성

# %%
import pandas as pd
#판다스라이이브러를 불러서 pd명령으로 짧게 호출할 수 있게 정의

# %% [markdown]
# # 1. 1차원 데이터

# %% [markdown]
# ## 1월부터 4월까지 강우량 (10, 20, 30, 40)

# %%
rain = pd.Series([10, 20, 30, 40])
rain
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
rain[0] # 1월 강우량
# 1차원선언에서는 첫번째 주소가 0, 두번째가 1, 4번째가 3으로 선언
# Out:
# 10

# %%
rain[2] # 3월 강우량
# Out:
# 30

# %% [markdown]
# # Index

# %%
rain = pd.Series([10, 20, 30, 40], index=['Jan', 'Feb', 'Mar', 'Apr'])
print(rain)
# Out:
# Jan    10
# Feb    20
# Mar    30
# Apr    40
# dtype: int64

# %%
rain
# Out:
# Jan    10
# Feb    20
# Mar    30
# Apr    40
# dtype: int64

# %%
rain['Jan'] # Index Jan (1월) 에 해당하는 데이터 출력
# Out:
# 10

# %%
rain['Apr'] # Index Apr (4월) 에 해당하는 데이터 출력
# Out:
# 40
